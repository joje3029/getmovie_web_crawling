# %%
# 까보기 목표!! 왜 마지막놈은 2012년꺼만 저장하는가?
#아래의 스파이더맨으로 함을 함수로 하나 만들자.

import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service as ChromeService
import time

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)
options.add_argument('headless')
service = ChromeService(executable_path='C:/Users/admin/psm/chromedriver-win64/chromedriver.exe')
driver = webdriver.Chrome(service=service, options=options)

#url list 만드는 부분
test_url = 'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&qvt=0&query=2023%EB%85%84%20%EC%98%81%ED%99%94%20%EC%88%9C%EC%9C%84'

url_list = [] #url을 2023.~2012까지 만들어서 list에 저장

for year in range(2023, 2011, -1):  # 2023부터 2011까지 year를 1씩 감소시키면서 반복
    split1 = test_url.split('=')
    split2 = split1[4].split('%')
    chage_year = str(year)  # 연도를 현재 year 값으로 업데이트
    frist = test_url.replace(split1[-1], '')
    last = split1[-1].replace(split2[0], '')  # 기존 연도를 바꾸는 대신, 기존 연도를 삭제
    new_url = frist+ chage_year + last
    url_list.append(new_url)  # 새로운 URL을 url_list에 추가
    
# 상위 딕셔너리 초기화
result_dic = {}
middle_dic = {}

# 각 URL에 대해 반복
for url in url_list:
    
    # 페이지 로딩
    driver.get(url)
    time.sleep(10)

#     로딩한 페이지에서 li까지 찾음
    chartDiv = driver.find_element(By.CLASS_NAME, 'movie_audience_ranking')
    content_list = chartDiv.find_element(By.CLASS_NAME, '_content')
    li_list = content_list.find_elements(By.TAG_NAME, 'li')

    for li in li_list:
        movie_info = li.find_element(By.CLASS_NAME, 'movie_info')
        a_tag = movie_info.find_element(By.CLASS_NAME, 'movie_tit')  
        href=a_tag.get_attribute("href") #링크
        movie_title = a_tag.find_element(By.CLASS_NAME, 'scm_ellipsis_text')  # 영화제목
        movie_item = li.find_element(By.CLASS_NAME, 'movie_item')
        movie_date = movie_item.find_element(By.TAG_NAME, 'dd')  # 개봉일
    
        split1 = url.split('=')
        split2 = split1[4].split('%')
        chage_year = str(year)
        
        title = movie_title.text
        date = movie_date.text
#         value = f'{date} ({chage_year})'
        value = f'{title} ({date})'
        
        middle_dic[title]=date
    
    
    result_dic[chage_year] = middle_dic
        

# 상위 딕셔너리 출력
print(result_dic)
# 출력 내용 : 궁금증 왜 2012년만 된것인가?
# {'2012': {'도둑들': '2012.07.25. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_706")>)', '광해, 왕이 된 남자': '2012.09.13. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_711")>)', '어벤져스': '2012.04.26. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_716")>)', '늑대소년': '2012.10.31. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_721")>)', '다크 나이트 라이즈': '2012.07.19. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_726")>)', '레미제라블': '2012.12.19. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_731")>)', '타워': '2012.12.25. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_736")>)', '바람과 함께 사라지다': '2012.08.08. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_741")>)'}}
# Out:
# {'2012': {'범죄도시3': '2023.05.31.', '엘리멘탈': '2023.06.14.', '스즈메의 문단속': '2023.03.08.', '밀수': '2023.07.26.', '더 퍼스트 슬램덩크': '2023.01.04.', '가디언즈 오브 갤럭시: Volume 3': '2023.05.03.', '미션 임파서블: 데드 레코닝 PA...': '2023.07.12.', '콘크리트 유토피아': '2023.08.09.', '범죄도시2': '2022.05.18.', '아
selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service as ChromeService
import time

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)
options.add_argument('headless')
service = ChromeService(executable_path='C:/Users/admin/psm/chromedriver-win64/chromedriver.exe')
driver = webdriver.Chrome(service=service, options=options)

#url list 만드는 부분
test_url = 'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&qvt=0&query=2023%EB%85%84%20%EC%98%81%ED%99%94%20%EC%88%9C%EC%9C%84'

url_list = [] #url을 2023.~2012까지 만들어서 list에 저장

for year in range(2023, 2011, -1):  # 2023부터 2011까지 year를 1씩 감소시키면서 반복
    split1 = test_url.split('=')
    split2 = split1[4].split('%')
    chage_year = str(year)  # 연도를 현재 year 값으로 업데이트
    frist = test_url.replace(split1[-1], '')
    last = split1[-1].replace(split2[0], '')  # 기존 연도를 바꾸는 대신, 기존 연도를 삭제
    new_url = frist+ chage_year + last
    url_list.append(new_url)  # 새로운 URL을 url_list에 추가
    
# 상위 딕셔너리 초기화
result_dic = {}

# 각 URL에 대해 반복
for url in url_list:
    split1 = url.split('=')
    split2 = split1[4].split('%')
    chage_year = split2[0]
    
    # 페이지 로딩
    driver.implicitly_wait(10)
    driver.get(url)
    
    
#     로딩한 페이지에서 li까지 찾음
    chartDiv = driver.find_element(By.CLASS_NAME, 'movie_audience_ranking')
    content_list = chartDiv.find_elements(By.CLASS_NAME, '_content')
    
    middle_dic = {}
    for content in content_list:
        li_list = content.find_elements(By.TAG_NAME, 'li')
#         middle_dic = {} : 여기는 잘못된 자리 왜냐면 다 빈걸로 됨
        for li in li_list:
            movie_info = li.find_element(By.CLASS_NAME, 'movie_info')
            a_tag = movie_info.find_element(By.CLASS_NAME, 'movie_tit')  
            href=a_tag.get_attribute("href") #링크
            movie_title = a_tag.find_element(By.CLASS_NAME, 'scm_ellipsis_text')  # 영화제목
            movie_item = li.find_element(By.CLASS_NAME, 'movie_item')
            movie_date = movie_item.find_element(By.TAG_NAME, 'dd')  # 개봉일

            split1 = url.split('=')
            split2 = split1[4].split('%')
            chage_year = chage_year

            title = movie_title.text
            date = movie_date.text

            middle_dic[title]=date

            result_dic[chage_year] = middle_dic
#         result_dic[chage_year] = middle_dic
        

# 상위 딕셔너리 출력
print(result_dic)
# 출력 내용 : 궁금증 왜 2012년만 된것인가?
# {'2012': {'도둑들': '2012.07.25. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_706")>)', '광해, 왕이 된 남자': '2012.09.13. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_711")>)', '어벤져스': '2012.04.26. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_716")>)', '늑대소년': '2012.10.31. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_721")>)', '다크 나이트 라이즈': '2012.07.19. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_726")>)', '레미제라블': '2012.12.19. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_731")>)', '타워': '2012.12.25. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element_736")>)', '바람과 함께 사라지다': '2012.08.08. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element
텔라': '2014.11.06.', '겨울왕국': '2014.01.16.', '해적: 바다로 간 산적': '2014.08.06.', '수상한 그녀': '2014.01.22.', '트랜스포머: 사라진 시대': '2014.06.25.', '님아, 그 강을 건너지 마오': '2014.11.27.', '': ''}, '2013': {'7번방의 선물': '2013.01.23.', '변호인': '2013.12.18.', '설국열차': '2013.08.01.', '관상': '2013.09.11.', '아이언맨 3': '2013.04.25.', '베를린': '2013.01.30.', '은밀하게 위대하게': '2013.06.05.', '숨바꼭질': '2013.08.14.', '': ''}, '2012': {'도둑들': '2012.07.25.', '광해, 왕이 된 남자': '2012.09.13.', '어벤져스': '2012.04.26.', '늑대소년': '2012.10.31.', '다크 나이트 라이즈': '2012.07.19.', '레미제라블': '2012.12.19.', '타워': '2012.12.25.', '바람과 함께 사라지다': '2012.08.08.', '': ''}}

# %%
# 까보기 목표!! 왜 마지막놈은 2012년꺼만 저장하는가?
#아래의 스파이더맨으로 함을 함수로 하나 만들자.

import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service as ChromeService
import time

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)
options.add_argument('headless')
service = ChromeService(executable_path='C:/Users/admin/psm/chromedriver-win64/chromedriver.exe')
driver = webdriver.Chrome(service=service, options=options)

#url list 만드는 부분
test_url = 'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&qvt=0&query=2023%EB%85%84%20%EC%98%81%ED%99%94%20%EC%88%9C%EC%9C%84'

url_list = [] #url을 2023.~2012까지 만들어서 list에 저장

for year in range(2023, 2011, -1):  # 2023부터 2011까지 year를 1씩 감소시키면서 반복
    split1 = test_url.split('=')
    split2 = split1[4].split('%')
    chage_year = str(year)  # 연도를 현재 year 값으로 업데이트
    frist = test_url.replace(split1[-1], '')
    last = split1[-1].replace(split2[0], '')  # 기존 연도를 바꾸는 대신, 기존 연도를 삭제
    new_url = frist+ chage_year + last
    url_list.append(new_url)  # 새로운 URL을 url_list에 추가
    
# 상위 딕셔너리 초기화
result_dic = {}



i = 0
# 각 URL에 대해 반복
for url in url_list:
    split1 = url.split('=')
    split2 = split1[4].split('%')
    chage_year = split2[0]
    
    # 페이지 로딩
    driver.implicitly_wait(10)
    driver.get(url)
    
    
#     로딩한 페이지에서 li까지 찾음
    chartDiv = driver.find_element(By.CLASS_NAME, 'movie_audience_ranking')
    content_list = chartDiv.find_elements(By.CLASS_NAME, '_content')
    
    middle_dic = {}
    for content in content_list:
        li_list = content.find_elements(By.TAG_NAME, 'li')
#         middle_dic = {} : 여기는 잘못된 자리 왜냐면 다 빈걸로 됨
        for li in li_list:
            movie_info = li.find_element(By.CLASS_NAME, 'movie_info')
            a_tag = movie_info.find_element(By.CLASS_NAME, 'movie_tit')  
            href=a_tag.get_attribute("href") #링크
            movie_title = a_tag.find_element(By.CLASS_NAME, 'scm_ellipsis_text')  # 영화제목
            movie_item = li.find_element(By.CLASS_NAME, 'movie_item')
            movie_date = movie_item.find_element(By.TAG_NAME, 'dd')  # 개봉일

            split1 = url.split('=')
            split2 = split1[4].split('%')
            chage_year = chage_year

            title = movie_title.text
            date = movie_date.text

            middle_dic[title]=date

#             result_dic[chage_year] = middle_dic
        result_dic[chage_year] = middle_dic
        

# 상위 딕셔너리 출력
print(result_dic)
# 출력 내용 : 궁금증 왜 2012년만 된것인가?
# {'2012': {'도둑들': '2012.07.25. (<selenium.webdriver.remote.webelement.WebElement (session="94fd70afe908b5fcb87389437a856491", element="EF57D809CD837699C39277E82E1F8C00_element
'2017.10.03.', '군함도': '2017.07.26.', '청년경찰': '2017.08.09.', '': ''}, '2016': {'부산행': '2016.07.20.', '검사외전': '2016.02.03.', '캡틴 아메리카: 시빌 워': '2016.04.27.', '밀정': '2016.09.07.', '마스터': '2016.12.21.', '터널': '2016.08.10.', '인천상륙작전': '2016.07.27.', '럭키': '2016.10.13.', '': ''}, '2015': {'베테랑': '2015.08.05.', '암살': '2015.07.22.', '어벤져스: 에이지 오브 울트론': '2015.04.23.', '히말라야': '2015.12.16.', '내부자들': '2015.11.19.', '사도': '2015.09.16.', '킹스맨 : 시크릿 에이전트': '2015.02.11.', '미션 임파서블: 로그네이션': '2015.07.30.', '': ''}, '2014': {'명량': '2014.07.30.', '국제시장': '2014.12.17.', '인터스텔라': '2014.11.06.', '겨울왕국': '2014.01.16.', '해적: 바다로 간 산적': '2014.08.06.', '수상한 그녀': '2014.01.22.', '트랜스포머: 사라진 시대': '2014.06.25.', '님아, 그 강을 건너지 마오': '2014.11.27.', '': ''}, '2013': {'7번방의 선물': '2013.01.23.', '변호인': '2013.12.18.', '설국열차': '2013.08.01.', '관상': '2013.09.11.', '아이언맨 3': '2013.04.25.', '베를린': '2013.01.30.', '은밀하게 위대하게': '2013.06.05.', '숨바꼭질': '2013.08.14.', '': ''}, '2012': {'도둑들': '2012.07.25.', '광해, 왕이 된 남자': '2012.09.13.', '어벤져스': '2012.04.26.', '늑대소년': '2012.10.31.', '다크 나이트 라이즈': '2012.07.19.', '레미제라블': '2012.12.19.', '타워': '2012.12.25.', '바람과 함께 사라지다': '2012.08.08.', '': ''}}

# %%
print(len(middle_dic))
# Out:
# 9

# %%
# content_list.lenght()
len(content_list)
# Out:
# 13

# %%
for content in content_list:
    print(content.text) 
#display none이라서인가?
# Out:
# 15세 관람가
# 1
# 도둑들
# 개봉
# 2012.07.25.
# 누적
# 12,984,701명
# 다운로드 예고편
# 15세 관람가
# 2
# 광해, 왕이 된 남자
# 개봉
# 2012.09.13.
# 누적
# 12,324,062명
# 다운로드 예고편
# 12세 관람가
# 3
# 어벤져스
# 개봉
# 2012.04.26.
# 누적
# 7,087,184명
# 다운로드 예고편
# 15세 관람가
# 4
# 늑대소년
# 개봉
# 2012.10.31.
# 누적
# 7,069,786명
# 다운로드 예고편
# 15세 관람가
# 5
# 다크 나이트 라이즈
# 개봉
# 2012.07.19.
# 누적
# 6,428,574명
# 다운로드 예고편
# 12세 관람가
# 6
# 레미제라블
# 개봉
# 2012.12.19.
# 누적
# 5,942,438명
# 예매 다운로드
# 12세 관람가
# 7
# 타워
# 개봉
# 2012.12.25.
# 누적
# 5,181,228명
# 다운로드 예고편
# 12세 관람가
# 8
# 바람과 함께 사라지다
# 개봉
# 2012.08.08.
# 누적
# 4,909,944명
# 다운로드 예고편

# %%
#영화 텍스트가 개판으로 들어간것에 대한 조사 

def find_movie(test_url):
    import selenium
    from selenium import webdriver
    from selenium.webdriver.common.by import By
    from selenium.webdriver.common.keys import Keys
    from selenium.webdriver.chrome.service import Service as ChromeService
    import time

    options = webdriver.ChromeOptions()
    options.add_experimental_option("excludeSwitches", ["enable-automation"])
    options.add_experimental_option("useAutomationExtension", False)
    options.add_argument('headless')
    service = ChromeService(executable_path='C:/Users/admin/psm/chromedriver-win64/chromedriver.exe')
    driver = webdriver.Chrome(service=service, options=options)

    test_dic={}
    
#     test_url='https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&pkid=68&os=23527376&qvt=0&query=%EC%8A%A4%ED%8C%8C%EC%9D%B4%EB%8D%94%EB%A7%A8%3A%20%EB%85%B8%20%EC%9B%A8%EC%9D%B4%20%ED%99%88'
    driver.implicitly_wait(10)
    driver.get(test_url)
    
#     time.sleep(10)
    try:
        text=driver.find_element(By.CLASS_NAME,'text_expand') #
        a=text.find_element(By.TAG_NAME,'a')
        href = a.get_attribute('href')
        href

        driver.get(href)
        movie_title = driver.find_element(By.CLASS_NAME,'area_text_title')
        movie_title.text # 제목 가져옴
        content_text = driver.find_element(By.CLASS_NAME,'_content_text')
        content_text.text # 줄거리 가져옴
        info_group = driver.find_element(By.CLASS_NAME,'info_group')
        open_date=info_group.find_element(By.TAG_NAME,'dd') # 개봉일

        title = movie_title.text
        date = open_date.text
        content = content_text.text
        value = f'{content} ({date})'

        test_dic[title] = value
    except:
        print("문제 발생. 대상을 찾지못함. 넘김")
    
    return test_dic

########################################################

import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service as ChromeService
import time

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)
options.add_argument('headless')
service = ChromeService(executable_path='C:/Users/admin/psm/chromedriver-win64/chromedriver.exe')
driver = webdriver.Chrome(service=service, options=options)

#url list 만드는 부분
test_url = 'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&qvt=0&query=2023%EB%85%84%20%EC%98%81%ED%99%94%20%EC%88%9C%EC%9C%84'

url_list = [] #url을 2023.~2012까지 만들어서 list에 저장

for year in range(2023, 2011, -1):  # 2023부터 2011까지 year를 1씩 감소시키면서 반복
    split1 = test_url.split('=')
    split2 = split1[4].split('%')
    chage_year = str(year)  # 연도를 현재 year 값으로 업데이트
    frist = test_url.replace(split1[-1], '')
    last = split1[-1].replace(split2[0], '')  # 기존 연도를 바꾸는 대신, 기존 연도를 삭제
    new_url = frist+ chage_year + last
    url_list.append(new_url)  # 새로운 URL을 url_list에 추가
    
# 상위 딕셔너리 초기화
result_dic = {}



i = 0
# 각 URL에 대해 반복
for url in url_list:
    split1 = url.split('=')
    split2 = split1[4].split('%')
    chage_year = split2[0]
    
    # 페이지 로딩
    driver.implicitly_wait(10)
    driver.get(url)
    
    
#     로딩한 페이지에서 li까지 찾음
    chartDiv = driver.find_element(By.CLASS_NAME, 'movie_audience_ranking')
    content_list = chartDiv.find_elements(By.CLASS_NAME, '_content')
    
#     middle_dic = {}
    for content in content_list:
        li_list = content.find_elements(By.TAG_NAME, 'li')
#         middle_dic = {} : 여기는 잘못된 자리 왜냐면 다 빈걸로 됨
        for li in li_list:
            movie_info = li.find_element(By.CLASS_NAME, 'movie_info')
            a_tag = movie_info.find_element(By.CLASS_NAME, 'movie_tit')  
            href=a_tag.get_attribute("href") #링크

            test_dic=find_movie(href)
    
            split1 = url.split('=')
            split2 = split1[4].split('%')
            chage_year = chage_year

            title = movie_title.text
            date = movie_date.text

#             middle_dic[title]=date

#             result_dic[chage_year] = middle_dic
        result_dic[chage_year] = test_dic
        

# 상위 딕셔너리 출력
print(result_dic)
# Out:
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
 우연히 세상에 눈을 뿌리는 ‘눈요정 마을’에 가게 되고, 조각가가 꿈인 ‘눈요정 아티’를 만나 즐거운 시간을 보낸다. 그 때, 어디선가 날아든 거대한 용암괴물이 마을을 습격해 눈요정들을 모두 데리고 가는데... 과연, 뽀로로와 친구들은 눈요정들을 무사히 구출하고, 화이트 크리스마스를 맞이할 수 있을까요? (2014.12.11.)'}, '2013': {'밤의 여왕': '울트라 A급 소심남 ‘영수’. 할인쿠폰 하나에 목숨거는 찌질남에다 이효리 같은 완벽한 여자가 나타날지언정 여자에 대한 관심이 없어 연애라고는 한번도 해 보지 못한 매력없는 소심남의 지존이다. 그런 그가 우연히 점심을 먹으러 들린 샌드위치 카페에서 ‘희주’라는 알바생을 만나게 되고, 첫눈에 반하게 된다. 하지만 대범하지 못한 성격탓에 대화 한번 건네지 못한채 매일 점심을 샌드위치로 때우기를 수십일. 큰 마음을 먹고 떨리는 마음을 다스리며 장미꽃 한송이를 든채 그녀에게 용기내어 프로포즈를 한다. 다행히도 영수의 순수한 마음을 인정한 ‘희주’는 영수의 프로포즈를 흔쾌히 수락하고 마침내 둘은 결혼에 성공하게 된다. 세상을 다 가진 것 같은 영수의 신혼생활은 탄탄대로이며 행복지수는 높아만 가던 어느 날. 우연히 변기 뒤에서 심상치 않은 사진을 발견하게 된다. 입으로는 “에이…희주가 아닐꺼야”라고 외치지만, 이미 마음 속에서는 그녀에 대한 의심이 꿈틀거리기 시작하고 이내 그녀 몰래 아내의 흑역사를 조심조심 파헤쳐 나가기 시작하는데.... 천사 같은 외모, 일류 호텔급 요리 솜씨, 3개국어가 가능한 지적능력까지 겸비한 그녀. 울트라 A급 현모양처 ‘희주’ 속았다! 대한민국 대표 현모양처인줄로만 알았던 그녀에게 이토록 어두운 흑역사가 있었다니! “내 의심의 시작은 미약했으나, 집착의 끝은 창대하리라!” (2013.10.17.)'}, '2012': {'우리는 동물원을 샀다': "모험심 강하고 열정적인 칼럼니스트이자 두 아이들의 아버지 벤자민 미(맷 데이먼)! 최근, 사랑하는 아내를 잃은 그는 엄마의 빈자리를 슬퍼하는 아이들과 새롭게 시작하기 위해 이사를 결정하고, 마침내 마음에 쏙 드는 집을 찾게 된다. 하지만, 완벽하게만 보이는 그 집의 딱 한가지 문제는 바로 무려 200여 마리의 리얼 야생 동물들이 사는 폐장 직전의 동물원이 딸려 있는 것! 동물원의 '동'자도 모르는 벤자민은 모험심이 발동, 전 재산을 통틀어 동물원을 사기로 결심한다. 덜컥 동물원에 입성한 벤자민 가족은 헌신적인 사육사 켈리(스칼렛 요한슨)와 함께 동물원을 오픈하기 위한 인생 최고의 모험을 시작 ...

# %%
# 왜 매해 마지막꺼만 가져온것인가
def find_movie(test_url):
    import selenium
    from selenium import webdriver
    from selenium.webdriver.common.by import By
    from selenium.webdriver.common.keys import Keys
    from selenium.webdriver.chrome.service import Service as ChromeService
    import time

    options = webdriver.ChromeOptions()
    options.add_experimental_option("excludeSwitches", ["enable-automation"])
    options.add_experimental_option("useAutomationExtension", False)
    options.add_argument('headless')
    service = ChromeService(executable_path='C:/Users/admin/psm/chromedriver-win64/chromedriver.exe')
    driver = webdriver.Chrome(service=service, options=options)

    test_dic={}
    
#     test_url='https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&pkid=68&os=23527376&qvt=0&query=%EC%8A%A4%ED%8C%8C%EC%9D%B4%EB%8D%94%EB%A7%A8%3A%20%EB%85%B8%20%EC%9B%A8%EC%9D%B4%20%ED%99%88'
    driver.implicitly_wait(10)
    driver.get(test_url)
    
#     time.sleep(10)
    try:
        text=driver.find_element(By.CLASS_NAME,'text_expand') #
        a=text.find_element(By.TAG_NAME,'a')
        href = a.get_attribute('href')
        href

        driver.get(href)
        movie_title = driver.find_element(By.CLASS_NAME,'area_text_title')
        movie_title.text # 제목 가져옴
        content_text = driver.find_element(By.CLASS_NAME,'_content_text')
        content_text.text # 줄거리 가져옴
        info_group = driver.find_element(By.CLASS_NAME,'info_group')
        open_date=info_group.find_element(By.TAG_NAME,'dd') # 개봉일

        title = movie_title.text
        date = open_date.text
        content = content_text.text
        value = f'{content} ({date})'

        test_dic[title] = value
    except:
        print("문제 발생. 대상을 찾지못함. 넘김")
    
    return test_dic

########################################################

import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service as ChromeService
import time

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)
options.add_argument('headless')
service = ChromeService(executable_path='C:/Users/admin/psm/chromedriver-win64/chromedriver.exe')
driver = webdriver.Chrome(service=service, options=options)

#url list 만드는 부분
test_url = 'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&qvt=0&query=2023%EB%85%84%20%EC%98%81%ED%99%94%20%EC%88%9C%EC%9C%84'

url_list = [] #url을 2023.~2012까지 만들어서 list에 저장

for year in range(2023, 2011, -1):  # 2023부터 2011까지 year를 1씩 감소시키면서 반복
    split1 = test_url.split('=')
    split2 = split1[4].split('%')
    chage_year = str(year)  # 연도를 현재 year 값으로 업데이트
    frist = test_url.replace(split1[-1], '')
    last = split1[-1].replace(split2[0], '')  # 기존 연도를 바꾸는 대신, 기존 연도를 삭제
    new_url = frist+ chage_year + last
    url_list.append(new_url)  # 새로운 URL을 url_list에 추가
    
# 상위 딕셔너리 초기화
result_dic = {}



i = 0
# 각 URL에 대해 반복
for url in url_list:
    split1 = url.split('=')
    split2 = split1[4].split('%')
    chage_year = split2[0]
    
    # 페이지 로딩
    driver.implicitly_wait(10)
    driver.get(url)
    
    
#     로딩한 페이지에서 li까지 찾음
    chartDiv = driver.find_element(By.CLASS_NAME, 'movie_audience_ranking')
    content_list = chartDiv.find_elements(By.CLASS_NAME, '_content')
    
    middle_dic = {}
    for content in content_list:
        li_list = content.find_elements(By.TAG_NAME, 'li')
#         middle_dic = {} : 여기는 잘못된 자리 왜냐면 다 빈걸로 됨
        for li in li_list:
            movie_info = li.find_element(By.CLASS_NAME, 'movie_info')
            a_tag = movie_info.find_element(By.CLASS_NAME, 'movie_tit')  
            href=a_tag.get_attribute("href") #링크

            test_dic=find_movie(href)
    
            split1 = url.split('=')
            split2 = split1[4].split('%')
            chage_year = chage_year

            title = movie_title.text
            date = movie_date.text

            middle_dic[title]=date

#             result_dic[chage_year] = middle_dic
        result_dic[chage_year] = test_dic
        

# 상위 딕셔너리 출력
print(result_dic)
# Out:
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
# 문제 발생. 대상을 찾지못함. 넘김
�인 ‘눈요정 아티’를 만나 즐거운 시간을 보낸다. 그 때, 어디선가 날아든 거대한 용암괴물이 마을을 습격해 눈요정들을 모두 데리고 가는데... 과연, 뽀로로와 친구들은 눈요정들을 무사히 구출하고, 화이트 크리스마스를 맞이할 수 있을까요? (2014.12.11.)'}, '2013': {'밤의 여왕': '울트라 A급 소심남 ‘영수’. 할인쿠폰 하나에 목숨거는 찌질남에다 이효리 같은 완벽한 여자가 나타날지언정 여자에 대한 관심이 없어 연애라고는 한번도 해 보지 못한 매력없는 소심남의 지존이다. 그런 그가 우연히 점심을 먹으러 들린 샌드위치 카페에서 ‘희주’라는 알바생을 만나게 되고, 첫눈에 반하게 된다. 하지만 대범하지 못한 성격탓에 대화 한번 건네지 못한채 매일 점심을 샌드위치로 때우기를 수십일. 큰 마음을 먹고 떨리는 마음을 다스리며 장미꽃 한송이를 든채 그녀에게 용기내어 프로포즈를 한다. 다행히도 영수의 순수한 마음을 인정한 ‘희주’는 영수의 프로포즈를 흔쾌히 수락하고 마침내 둘은 결혼에 성공하게 된다. 세상을 다 가진 것 같은 영수의 신혼생활은 탄탄대로이며 행복지수는 높아만 가던 어느 날. 우연히 변기 뒤에서 심상치 않은 사진을 발견하게 된다. 입으로는 “에이…희주가 아닐꺼야”라고 외치지만, 이미 마음 속에서는 그녀에 대한 의심이 꿈틀거리기 시작하고 이내 그녀 몰래 아내의 흑역사를 조심조심 파헤쳐 나가기 시작하는데.... 천사 같은 외모, 일류 호텔급 요리 솜씨, 3개국어가 가능한 지적능력까지 겸비한 그녀. 울트라 A급 현모양처 ‘희주’ 속았다! 대한민국 대표 현모양처인줄로만 알았던 그녀에게 이토록 어두운 흑역사가 있었다니! “내 의심의 시작은 미약했으나, 집착의 끝은 창대하리라!” (2013.10.17.)'}, '2012': {'우리는 동물원을 샀다': "모험심 강하고 열정적인 칼럼니스트이자 두 아이들의 아버지 벤자민 미(맷 데이먼)! 최근, 사랑하는 아내를 잃은 그는 엄마의 빈자리를 슬퍼하는 아이들과 새롭게 시작하기 위해 이사를 결정하고, 마침내 마음에 쏙 드는 집을 찾게 된다. 하지만, 완벽하게만 보이는 그 집의 딱 한가지 문제는 바로 무려 200여 마리의 리얼 야생 동물들이 사는 폐장 직전의 동물원이 딸려 있는 것! 동물원의 '동'자도 모르는 벤자민은 모험심이 발동, 전 재산을 통틀어 동물원을 사기로 결심한다. 덜컥 동물원에 입성한 벤자민 가족은 헌신적인 사육사 켈리(스칼렛 요한슨)와 함께 동물원을 오픈하기 위한 인생 최고의 모험을 시작 ...

# %%
# 왜 매해 마지막꺼만 가져온것인가
def find_movie(test_url):
    import selenium
    from selenium import webdriver
    from selenium.webdriver.common.by import By
    from selenium.webdriver.common.keys import Keys
    from selenium.webdriver.chrome.service import Service as ChromeService
    import time

    options = webdriver.ChromeOptions()
    options.add_experimental_option("excludeSwitches", ["enable-automation"])
    options.add_experimental_option("useAutomationExtension", False)
    options.add_argument('headless')
    service = ChromeService(executable_path='C:/Users/admin/psm/chromedriver-win64/chromedriver.exe')
    driver = webdriver.Chrome(service=service, options=options)

    test_dic={}
    
#     test_url='https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&pkid=68&os=23527376&qvt=0&query=%EC%8A%A4%ED%8C%8C%EC%9D%B4%EB%8D%94%EB%A7%A8%3A%20%EB%85%B8%20%EC%9B%A8%EC%9D%B4%20%ED%99%88'
    driver.implicitly_wait(10)
    driver.get(test_url)
    
#     time.sleep(10)
    try:
        text=driver.find_element(By.CLASS_NAME,'text_expand') #
        a=text.find_element(By.TAG_NAME,'a')
        href = a.get_attribute('href')
        href

        driver.get(href)
        movie_title = driver.find_element(By.CLASS_NAME,'area_text_title')
        movie_title.text # 제목 가져옴
        content_text = driver.find_element(By.CLASS_NAME,'_content_text')
        content_text.text # 줄거리 가져옴
        info_group = driver.find_element(By.CLASS_NAME,'info_group')
        open_date=info_group.find_element(By.TAG_NAME,'dd') # 개봉일

        title = movie_title.text
        date = open_date.text
        content = content_text.text
        value = f'{content} ({date})'

        test_dic[title] = value
    except:
        print("문제 발생. 대상을 찾지못함. 넘김")
    
    return test_dic

########################################################

import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service as ChromeService
import time

options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)
options.add_argument('headless')
service = ChromeService(executable_path='C:/Users/admin/psm/chromedriver-win64/chromedriver.exe')
driver = webdriver.Chrome(service=service, options=options)

#url list 만드는 부분
test_url = 'https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&qvt=0&query=2023%EB%85%84%20%EC%98%81%ED%99%94%20%EC%88%9C%EC%9C%84'

url_list = [] #url을 2023.~2012까지 만들어서 list에 저장

for year in range(2023, 2011, -1):  # 2023부터 2011까지 year를 1씩 감소시키면서 반복
    split1 = test_url.split('=')
    split2 = split1[4].split('%')
    chage_year = str(year)  # 연도를 현재 year 값으로 업데이트
    frist = test_url.replace(split1[-1], '')
    last = split1[-1].replace(split2[0], '')  # 기존 연도를 바꾸는 대신, 기존 연도를 삭제
    new_url = frist+ chage_year + last
    url_list.append(new_url)  # 새로운 URL을 url_list에 추가
    
# 상위 딕셔너리 초기화
result_dic = {}


i = 0
# 각 URL에 대해 반복
for url in url_list:
    split1 = url.split('=')
    split2 = split1[4].split('%')
    chage_year = split2[0]
    
    # 페이지 로딩
    driver.implicitly_wait(10)
    driver.get(url)
    
    
#     로딩한 페이지에서 li까지 찾음
    chartDiv = driver.find_element(By.CLASS_NAME, 'movie_audience_ranking')
    content_list = chartDiv.find_elements(By.CLASS_NAME, '_content')
    
    test_dic = {}
    for content in content_list:
        li_list = content.find_elements(By.TAG_NAME, 'li')
#         middle_dic = {} : 여기는 잘못된 자리 왜냐면 다 빈걸로 됨
        for li in li_list:
            movie_info = li.find_element(By.CLASS_NAME, 'movie_info')
            a_tag = movie_info.find_element(By.CLASS_NAME, 'movie_tit')  
            href=a_tag.get_attribute("href") #링크

            test_dic=find_movie(href)
    
            split1 = url.split('=')
            split2 = split1[4].split('%')
            chage_year = chage_year

            title = movie_title.text
            date = movie_date.text

#             result_dic[chage_year] = middle_dic
        result_dic[chage_year] = test_dic
        

# 상위 딕셔너리 출력
print(result_dic)
